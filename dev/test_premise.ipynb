# %%
from premise import *
from datapackage import Package
import bw2data, bw2io, bw2calc
from unfold import Unfold
bw2data.projects.set_current("new4")

# %%
clear_cache()
# Out:
# Cache folder cleared!

# %%
combinations = [
    {"range time":False, "duration":False, "foresight":False, "lead time":False, "capital replacement rate":False, "measurement": 5, "weighted slope start": 0.75, "weighted slope end": 1.00},
    {"range time":False, "duration":False, "foresight":False, "lead time":False, "capital replacement rate":False, "measurement": 0, "weighted slope start": 0.75, "weighted slope end": 1.00},
    {"range time":2, "duration":False, "foresight":False, "lead time":False, "capital replacement rate":False, "measurement": 0, "weighted slope start": 0.75, "weighted slope end": 1.00},
    {"range time":2, "duration":False, "foresight":False, "lead time":True, "capital replacement rate":False, "measurement": 0, "weighted slope start": 0.75, "weighted slope end": 1.00},
    {"range time":2, "duration":False, "foresight":True, "lead time":False, "capital replacement rate":False, "measurement": 0, "weighted slope start": 0.75, "weighted slope end": 1.00},
    {"range time":2, "duration":False, "foresight":False, "lead time":False, "capital replacement rate":False, "measurement": 1, "weighted slope start": 0.75, "weighted slope end": 1.00},
    {"range time":2, "duration":False, "foresight":False, "lead time":False, "capital replacement rate":False, "measurement": 2, "weighted slope start": 0.75, "weighted slope end": 1.00},
    {"range time":2, "duration":False, "foresight":False, "lead time":False, "capital replacement rate":False, "measurement": 3, "weighted slope start": 0.75, "weighted slope end": 1.00},
    {"range time":2, "duration":False, "foresight":False, "lead time":False, "capital replacement rate":True, "measurement": 0, "weighted slope start": 0.75, "weighted slope end": 1.00},
    {"range time":False, "duration":20, "foresight":False, "lead time":False, "capital replacement rate":False, "measurement": 0, "weighted slope start": 0.75, "weighted slope end": 1.00},
    {"range time":False, "duration":20, "foresight":False, "lead time":True, "capital replacement rate":False, "measurement": 0, "weighted slope start": 0.75, "weighted slope end": 1.00},
    {"range time":False, "duration":20, "foresight":True, "lead time":False, "capital replacement rate":False, "measurement": 0, "weighted slope start": 0.75, "weighted slope end": 1.00},
    {"range time":False, "duration":20, "foresight":False, "lead time":False, "capital replacement rate":False, "measurement": 1, "weighted slope start": 0.75, "weighted slope end": 1.00},
    {"range time":False, "duration":20, "foresight":False, "lead time":False, "capital replacement rate":False, "measurement": 2, "weighted slope start": 0.75, "weighted slope end": 1.00},
    {"range time":False, "duration":20, "foresight":False, "lead time":False, "capital replacement rate":False, "measurement": 3, "weighted slope start": 0.75, "weighted slope end": 1.00},
    {"range time":False, "duration":20, "foresight":False, "lead time":False, "capital replacement rate":True, "measurement": 0, "weighted slope start": 0.75, "weighted slope end": 1.00},
    {"range time":False, "duration":20, "foresight":False, "lead time":False, "capital replacement rate":False, "measurement": 4, "weighted slope start": 0.75, "weighted slope end": 1.00},
    {"range time":False, "duration":20, "foresight":True, "lead time":False, "capital replacement rate":False, "measurement": 4, "weighted slope start": 0.75, "weighted slope end": 1.00},
    {"range time":False, "duration":20, "foresight":False, "lead time":False, "capital replacement rate":True, "measurement": 4, "weighted slope start": 0.75, "weighted slope end": 1.00}
]

# %%
scenarios = [
    {"model": "remind", "pathway":"SSP2-Base", "year": 2050},
    {"model": "image", "pathway":"SSP2-RCP19", "year": 2050},
]

for model in [
    "cutoff",
    "consequential"
]:

    for ei in [
        #"3.6",
        #"3.7",
        #"3.7.1",
        #"3.8",
        #"3.9",
        "3.9.1"

    ]:
        
        if ei not in ["3.9", "3.9.1"]:
            bw2data.projects.set_current("new4")
        else:
            bw2data.projects.set_current("ei39")

        for source in [
            "brightway",
            #"ecospold"
        ]:
            for export in [
                "brightway",
                "superstructure",
                "simapro",
                "matrices",
                "datapackage"
            ]:

                ndb = NewDatabase(
                        scenarios = scenarios,
                        source_db= f"ecoinvent {ei} {model}" if source == "brightway" else None,
                        source_type=source,
                        source_file_path=f"/Users/romain/Documents/ecoinvent {ei}_cutoff_ecoSpold02/datasets" if source == "ecospold" else None, # <-- this is NEW
                        source_version=ei,
                        key='tUePmX_S5B8ieZkkM7WUU2CnO8SmShwmAeWK9x2rTFo=',
                        system_model=model,
                        system_args=combinations[0],
                        additional_inventories= [ # <-- this is NEW
                            {"filepath": "/Users/romain/GitHub/premise/premise/data/additional_inventories/lci-PV.xlsx", "ecoinvent version": "3.7"}, # <-- this is NEW
                    ] # <-- this is NEW
                )
                

                print("#############################################################################################################")
                print(ei, source, export)

                ndb.update_buses()
                ndb.update_cars()
                ndb.update_two_wheelers()
                ndb.update_all()
                #ndb.update_electricity()
                
                #ndb.update_trucks()
                


                if export == "brightway":
                        
                    ndb.write_db_to_brightway([
                        "test1",
                        "test2"
                        ]
                    )
                    lca = bw2calc.LCA({bw2data.Database("test1").random(): 1})
                    lca.lci()
                    lca = bw2calc.LCA({bw2data.Database("test2").random(): 1})
                    lca.lci()
                elif export == "superstructure":
                    ndb.write_superstructure_db_to_brightway("test_super")
                elif export == "simapro":
                    ndb.write_db_to_simapro()
                elif export == "matrices":
                    ndb.write_db_to_matrices()
                else:
                    ndb.write_datapackage(name="test")
                    u = Unfold("export/datapackage/test.zip")
                    u.unfold(dependencies={"ecoinvent": f"ecoinvent {ei} {model}", "biosphere3": "biosphere3"}, superstructure=True)
# Out:
# premise v.(1, 8, 2, 'dev7')
# +------------------------------------------------------------------+
# | Warning                                                          |
# +------------------------------------------------------------------+
# | Because some of the scenarios can yield LCI databases            |
# | containing net negative emission technologies (NET),             |
# | it is advised to account for biogenic CO2 flows when calculating |
# | Global Warming potential indicators.                             |
# | `premise_gwp` provides characterization factors for such flows.  |
# | It also provides factors for hydrogen emissions to air.          |
# |                                                                  |
# | Within your bw2 project:                                         |
# | from premise_gwp import add_premise_gwp                          |
# | add_premise_gwp()                                                |
# +------------------------------------------------------------------+
# +--------------------------------+----------------------------------+
# | Utils functions                | Description                      |
# +--------------------------------+----------------------------------+
# | clear_cache()                  | Clears the cache folder. Useful  |
# |                                | when updating `premise`or        |
# |                                | encountering issues with         |
# |                                | inventories.                     |
# +--------------------------------+----------------------------------+
# | get_regions_definition(model)  | Retrieves the list of countries  |
# |                                | for each region of the model.    |
# +--------------------------------+----------------------------------+
# | ndb.NewDatabase(...)           | Generates a summary of the most  |
# | ndb.generate_scenario_report() | important scenarios' variables.  |
# +--------------------------------+----------------------------------+
# Keep uncertainty data?
# NewDatabase(..., keep_uncertainty_data=True)
#
# Disable multiprocessing?
# NewDatabase(..., use_multiprocessing=False)
#
# Hide these messages?
# NewDatabase(..., quiet=True)
#
# //////////////////// EXTRACTING SOURCE DATABASE ////////////////////
# Done!
#
# ////////////////// IMPORTING DEFAULT INVENTORIES ///////////////////
#
# //////////////// IMPORTING USER-DEFINED INVENTORIES ////////////////
# Extracted 1 worksheets in 0.46 seconds
# Migrating to 3.8 first
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# The following datasets to import already exist in the source database. They will not be imported
# +--------------------------------+--------------------------------+----------+-------------+
# |              Name              |       Reference product        | Location |     File    |
# +--------------------------------+--------------------------------+----------+-------------+
# |       bromine, at plant        |       bromine, at plant        |   RER    | lci-PV.xlsx |
# | electricity production, photov |    electricity, low voltage    |    PT    | lci-PV.xlsx |
# | electricity production, photov |    electricity, low voltage    |    IL    | lci-PV.xlsx |
# | electricity production, photov |    electricity, low voltage    |    SE    | lci-PV.xlsx |
# | electricity production, photov |    electricity, low voltage    |    FR    | lci-PV.xlsx |
# | electricity production, photov |    electricity, low voltage    |    TR    | lci-PV.xlsx |
# | electricity production, photov |    electricity, low voltage    |    NZ    | lci-PV.xlsx |
# | electricity production, photov |    electricity, low voltage    |    MY    | lci-PV.xlsx |
# | electricity production, photov |    electricity, low voltage    |    CN    | lci-PV.xlsx |
# | electricity production, photov |    electricity, low voltage    |    TH    | lci-PV.xlsx |
# | electricity production, photov |    electricity, low voltage    |    ZA    | lci-PV.xlsx |
# | electricity production, photov |    electricity, low voltage    |    JP    | lci-PV.xlsx |
# | electricity production, photov |    electricity, low voltage    |    CH    | lci-PV.xlsx |
# | electricity production, photov |    electricity, low voltage    |    DE    | lci-PV.xlsx |
# | electricity production, photov |    electricity, low voltage    |    KR    | lci-PV.xlsx |
# | electricity production, photov |    electricity, low voltage    |    AT    | lci-PV.xlsx |
# | electricity production, photov |    electricity, low voltage    |    GR    | lci-PV.xlsx |
# | electricity production, photov |    electricity, low voltage    |    IE    | lci-PV.xlsx |
# | electricity production, photov |    electricity, low voltage    |    AU    | lci-PV.xlsx |
# | electricity production, photov |    electricity, low voltage    |    IT    | lci-PV.xlsx |
# | electricity production, photov |    electricity, low voltage    |    MX    | lci-PV.xlsx |
# | emulsion polymerisation, polyv | emulsion polymerisation, polyv |   RER    | lci-PV.xlsx |
# |   ethylene bromide, at plant   |   ethylene bromide, at plant   |   RER    | lci-PV.xlsx |
# | fluorspar production, 97% puri |     fluorspar, 97% purity      |   GLO    | lci-PV.xlsx |
# |  hydrogen fluoride production  |       hydrogen fluoride        |   GLO    | lci-PV.xlsx |
# |             iodine             |             iodine             |   RER    | lci-PV.xlsx |
# | metallization paste production | metallization paste, back side |   RER    | lci-PV.xlsx |
# | metallization paste production | metallization paste, back side |   RER    | lci-PV.xlsx |
# | metallization paste production | metallization paste, front sid |   RER    | lci-PV.xlsx |
# |         methyl iodide          |         methyl iodide          |   RER    | lci-PV.xlsx |
# | nitrogen trifluoride, at plant | nitrogen trifluoride, at plant |   RER    | lci-PV.xlsx |
# | open ground construction, on g | open ground construction, on g |   RER    | lci-PV.xlsx |
# |   photovoltaic cell factory    |   photovoltaic cell factory    |    DE    | lci-PV.xlsx |
# | photovoltaic module production | photovoltaic module, building- |   RER    | lci-PV.xlsx |
# | photovoltaic module production | photovoltaic module, building- |   RER    | lci-PV.xlsx |
# | photovoltaic mounting system p | photovoltaic mounting system,  |   RER    | lci-PV.xlsx |
# | photovoltaic mounting system p | photovoltaic mounting system,  |   RER    | lci-PV.xlsx |
# | photovoltaic mounting system p | photovoltaic mounting system,  |   RER    | lci-PV.xlsx |
# | photovoltaic panel factory con |   photovoltaic panel factory   |   GLO    | lci-PV.xlsx |
# |   polyvinylalcohol, at plant   |   polyvinylalcohol, at plant   |   RER    | lci-PV.xlsx |
# | polyvinylbutyral foil, at plan | polyvinylbutyral foil, at plan |   RER    | lci-PV.xlsx |
# | polyvinylbutyral, powder, at p | polyvinylbutyral, powder, at p |   RER    | lci-PV.xlsx |
# |  polyvinylfluoride production  |       polyvinylfluoride        |    US    | lci-PV.xlsx |
# | polyvinylfluoride production,  | polyvinylfluoride, dispersion  |    US    | lci-PV.xlsx |
# | polyvinylfluoride, film produc |    polyvinylfluoride, film     |    US    | lci-PV.xlsx |
# |        silane, at plant        |        silane, at plant        |   RER    | lci-PV.xlsx |
# | silicon production, metallurgi |  silicon, metallurgical grade  |    NO    | lci-PV.xlsx |
# | silicon production, metallurgi |  silicon, metallurgical grade  |    CN    | lci-PV.xlsx |
# | silicon production, metallurgi |  silicon, metallurgical grade  |    US    | lci-PV.xlsx |
# | silicon production, metallurgi |  silicon, metallurgical grade  |   APAC   | lci-PV.xlsx |
# | silicon production, photovolta | silicon production, photovolta |   GLO    | lci-PV.xlsx |
# | silicon production, photovolta | silicon production, photovolta |    CN    | lci-PV.xlsx |
# | silicon production, photovolta | silicon production, photovolta |   APAC   | lci-PV.xlsx |
# | silicon production, photovolta | silicon production, photovolta |    US    | lci-PV.xlsx |
# |   vinyl fluoride production    |         vinyl fluoride         |    US    | lci-PV.xlsx |
# |   wafer factory construction   |         wafer factory          |    DE    | lci-PV.xlsx |
# | electricity production, photov |    electricity, low voltage    |    AU    | lci-PV.xlsx |
# | electricity production, photov |    electricity, low voltage    |    AT    | lci-PV.xlsx |
# | electricity production, photov |    electricity, low voltage    |    BE    | lci-PV.xlsx |
# | electricity production, photov |    electricity, low voltage    |    CA    | lci-PV.xlsx |
# | electricity production, photov |    electricity, low voltage    |    CL    | lci-PV.xlsx |
# | electricity production, photov |    electricity, low voltage    |    CN    | lci-PV.xlsx |
# | electricity production, photov |    electricity, low voltage    |    CZ    | lci-PV.xlsx |
# | electricity production, photov |    electricity, low voltage    |    DK    | lci-PV.xlsx |
# | electricity production, photov |    electricity, low voltage    |    FI    | lci-PV.xlsx |
# | electricity production, photov |    electricity, low voltage    |    FR    | lci-PV.xlsx |
# | electricity production, photov |    electricity, low voltage    |    DE    | lci-PV.xlsx |
# | electricity production, photov |    electricity, low voltage    |    GR    | lci-PV.xlsx |
# | electricity production, photov |    electricity, low voltage    |    HU    | lci-PV.xlsx |
# | electricity production, photov |    electricity, low voltage    |    IE    | lci-PV.xlsx |
# | electricity production, photov |    electricity, low voltage    |    IL    | lci-PV.xlsx |
# | electricity production, photov |    electricity, low voltage    |    IT    | lci-PV.xlsx |
# | electricity production, photov |    electricity, low voltage    |    JP    | lci-PV.xlsx |
# | electricity production, photov |    electricity, low voltage    |    KR    | lci-PV.xlsx |
# | electricity production, photov |    electricity, low voltage    |    LU    | lci-PV.xlsx |
# | electricity production, photov |    electricity, low voltage    |    MY    | lci-PV.xlsx |
# | electricity production, photov |    electricity, low voltage    |    MX    | lci-PV.xlsx |
# | electricity production, photov |    electricity, low voltage    |    NL    | lci-PV.xlsx |
# | electricity production, photov |    electricity, low voltage    |    NZ    | lci-PV.xlsx |
# | electricity production, photov |    electricity, low voltage    |    NO    | lci-PV.xlsx |
# | electricity production, photov |    electricity, low voltage    |    PT    | lci-PV.xlsx |
# | electricity production, photov |    electricity, low voltage    |    ZA    | lci-PV.xlsx |
# | electricity production, photov |    electricity, low voltage    |    ES    | lci-PV.xlsx |
# | electricity production, photov |    electricity, low voltage    |    SE    | lci-PV.xlsx |
# | electricity production, photov |    electricity, low voltage    |    CH    | lci-PV.xlsx |
# | electricity production, photov |    electricity, low voltage    |    TH    | lci-PV.xlsx |
# | electricity production, photov |    electricity, low voltage    |    TR    | lci-PV.xlsx |
# | electricity production, photov |    electricity, low voltage    |    GB    | lci-PV.xlsx |
# | electricity production, photov |    electricity, low voltage    |    US    | lci-PV.xlsx |
# | electricity production, photov |    electricity, low voltage    |    AU    | lci-PV.xlsx |
# | electricity production, photov |    electricity, low voltage    |    AT    | lci-PV.xlsx |
# | electricity production, photov |    electricity, low voltage    |    BE    | lci-PV.xlsx |
# | electricity production, photov |    electricity, low voltage    |    CA    | lci-PV.xlsx |
# | electricity production, photov |    electricity, low voltage    |    CL    | lci-PV.xlsx |
# | electricity production, photov |    electricity, low voltage    |    CN    | lci-PV.xlsx |
# | electricity production, photov |    electricity, low voltage    |    CZ    | lci-PV.xlsx |
# | electricity production, photov |    electricity, low voltage    |    DK    | lci-PV.xlsx |
# | electricity production, photov |    electricity, low voltage    |    FI    | lci-PV.xlsx |
# | electricity production, photov |    electricity, low voltage    |    FR    | lci-PV.xlsx |
# | electricity production, photov |    electricity, low voltage    |    DE    | lci-PV.xlsx |
# | electricity production, photov |    electricity, low voltage    |    GR    | lci-PV.xlsx |
# | electricity production, photov |    electricity, low voltage    |    HU    | lci-PV.xlsx |
# | electricity production, photov |    electricity, low voltage    |    IE    | lci-PV.xlsx |
# | electricity production, photov |    electricity, low voltage    |    IL    | lci-PV.xlsx |
# | electricity production, photov |    electricity, low voltage    |    IT    | lci-PV.xlsx |
# | electricity production, photov |    electricity, low voltage    |    JP    | lci-PV.xlsx |
# | electricity production, photov |    electricity, low voltage    |    KR    | lci-PV.xlsx |
# | electricity production, photov |    electricity, low voltage    |    LU    | lci-PV.xlsx |
# | electricity production, photov |    electricity, low voltage    |    MY    | lci-PV.xlsx |
# | electricity production, photov |    electricity, low voltage    |    MX    | lci-PV.xlsx |
# | electricity production, photov |    electricity, low voltage    |    NL    | lci-PV.xlsx |
# | electricity production, photov |    electricity, low voltage    |    NZ    | lci-PV.xlsx |
# | electricity production, photov |    electricity, low voltage    |    NO    | lci-PV.xlsx |
# | electricity production, photov |    electricity, low voltage    |    PT    | lci-PV.xlsx |
# | electricity production, photov |    electricity, low voltage    |    ZA    | lci-PV.xlsx |
# | electricity production, photov |    electricity, low voltage    |    ES    | lci-PV.xlsx |
# | electricity production, photov |    electricity, low voltage    |    SE    | lci-PV.xlsx |
# | electricity production, photov |    electricity, low voltage    |    CH    | lci-PV.xlsx |
# | electricity production, photov |    electricity, low voltage    |    TH    | lci-PV.xlsx |
# | electricity production, photov |    electricity, low voltage    |    TR    | lci-PV.xlsx |
# | electricity production, photov |    electricity, low voltage    |    GB    | lci-PV.xlsx |
# | electricity production, photov |    electricity, low voltage    |    US    | lci-PV.xlsx |
# +--------------------------------+--------------------------------+----------+-------------+
# Migrating to 3.8 first
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Done!
#
# /////////////////////// EXTRACTING IAM DATA ////////////////////////
# Done!
# #############################################################################################################
# 3.9.1 brightway brightway
#
# ////////////////////////////// BUSES ///////////////////////////////
# Extracted 1 worksheets in 0.99 seconds
# Migrating to 3.8 first
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Done!
#
#
# ///////////////////////// PASSENGER CARS ///////////////////////////
# No markets found for car in IAM data. Skipping.
# Done!
#
#
# ////////////////////////// TWO-WHEELERS ////////////////////////////
# No markets found for two wheeler in IAM data. Skipping.
# Done!
#
# `update_all()` will skip the following steps:
# update_two_wheelers(), update_cars(), and update_buses()
# If you want to update these steps, please run them separately afterwards.
# Extracted 1 worksheets in 4.11 seconds
# Migrating to 3.8 first
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# The following datasets to import already exist in the source database. They will not be imported
# +--------------------------------+--------------------------------+----------+-----------------+
# |              Name              |       Reference product        | Location |       File      |
# +--------------------------------+--------------------------------+----------+-----------------+
# |      electrical equipment      |      electrical equipment      |   RER    | lci-trucks.xlsx |
# |       gearbox, for lorry       |       gearbox, for lorry       |   RER    | lci-trucks.xlsx |
# | fuel tank, for diesel vehicle  |           fuel tank            |   RER    | lci-trucks.xlsx |
# |    transmission, for lorry     |    transmission, for lorry     |   RER    | lci-trucks.xlsx |
# |     suspension, for lorry      |     suspension, for lorry      |   RER    | lci-trucks.xlsx |
# | fuel tank, compressed hydrogen | fuel tank, compressed hydrogen |   GLO    | lci-trucks.xlsx |
# |        storage battery         |        storage battery         |   RER    | lci-trucks.xlsx |
# |  power electronics, for lorry  |  power electronics, for lorry  |   RER    | lci-trucks.xlsx |
# |  lead acid battery, for lorry  |  lead acid battery, for lorry  |   RER    | lci-trucks.xlsx |
# | other components, for hybrid e | other components, for hybrid e |   RER    | lci-trucks.xlsx |
# |            charger             |            charger             |   RER    | lci-trucks.xlsx |
# |          transformers          |          transformers          |   RER    | lci-trucks.xlsx |
# | fuel tank, compressed hydrogen |         hydrogen tank          |   RER    | lci-trucks.xlsx |
# | other components, for electric | other components, for electric |   RER    | lci-trucks.xlsx |
# |      retarder, for lorry       |      retarder, for lorry       |   RER    | lci-trucks.xlsx |
# | assembly operation, for lorry  | assembly operation, for lorry  |   RER    | lci-trucks.xlsx |
# |         charging stand         |         charging stand         |   RER    | lci-trucks.xlsx |
# |   exhaust system, for lorry    |   exhaust system, for lorry    |   RER    | lci-trucks.xlsx |
# |        cabin, for lorry        |        cabin, for lorry        |   RER    | lci-trucks.xlsx |
# | fuel tank, compressed natural  | fuel tank, compressed natural  |   RER    | lci-trucks.xlsx |
# |     glider lightweighting      |     glider lightweighting      |   GLO    | lci-trucks.xlsx |
# | frame, blanks and saddle, for  | frame, blanks and saddle, for  |   RER    | lci-trucks.xlsx |
# | internal combustion engine, fo | internal combustion engine, fo |   RER    | lci-trucks.xlsx |
# |  tires and wheels, for lorry   |  tires and wheels, for lorry   |   RER    | lci-trucks.xlsx |
# +--------------------------------+--------------------------------+----------+-----------------+
# Anomalies found: check the change report.
# Done!
# Done!
# Extracted 1 worksheets in 4.32 seconds
# Migrating to 3.8 first
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Anomalies found: check the change report.
# Done!
# Done!
# Done!
#
# Write new database(s) to Brightway.
# Running all checks...
# Anomalies found: check the change report.
# Running all checks...
# Database test1 already exists: it will be overwritten.
# Vacuuming database
# Writing activities to SQLite3 database:
# 0% [##############################] 100% | ETA: 00:00:00
# Total time elapsed: 00:00:39
# Title: Writing activities to SQLite3 database:
#   Started: 01/30/2024 10:50:36
#   Finished: 01/30/2024 10:51:16
#   Total time elapsed: 00:00:39
#   CPU %: 93.50
#   Memory %: 11.81
# Created database: test1
# Database test2 already exists: it will be overwritten.
# Vacuuming database
# Writing activities to SQLite3 database:
# 0% [##############################] 100% | ETA: 00:00:00
# Total time elapsed: 00:00:30
# Title: Writing activities to SQLite3 database:
#   Started: 01/30/2024 10:54:09
#   Finished: 01/30/2024 10:54:39
#   Total time elapsed: 00:00:30
#   CPU %: 96.30
#   Memory %: 17.32
# Created database: test2
# Generate scenario report.
# Report saved under /Users/romain/GitHub/premise/dev/export/scenario_report.
# Generate change report.
# Report saved under /Users/romain/GitHub/premise/dev.
# premise v.(1, 8, 2, 'dev7')
# +------------------------------------------------------------------+
# | Warning                                                          |
# +------------------------------------------------------------------+
# | Because some of the scenarios can yield LCI databases            |
# | containing net negative emission technologies (NET),             |
# | it is advised to account for biogenic CO2 flows when calculating |
# | Global Warming potential indicators.                             |
# | `premise_gwp` provides characterization factors for such flows.  |
# | It also provides factors for hydrogen emissions to air.          |
# |                                                                  |
# | Within your bw2 project:                                         |
# | from premise_gwp import add_premise_gwp                          |
# | add_premise_gwp()                                                |
# +------------------------------------------------------------------+
# +--------------------------------+----------------------------------+
# | Utils functions                | Description                      |
# +--------------------------------+----------------------------------+
# | clear_cache()                  | Clears the cache folder. Useful  |
# |                                | when updating `premise`or        |
# |                                | encountering issues with         |
# |                                | inventories.                     |
# +--------------------------------+----------------------------------+
# | get_regions_definition(model)  | Retrieves the list of countries  |
# |                                | for each region of the model.    |
# +--------------------------------+----------------------------------+
# | ndb.NewDatabase(...)           | Generates a summary of the most  |
# | ndb.generate_scenario_report() | important scenarios' variables.  |
# +--------------------------------+----------------------------------+
# Keep uncertainty data?
# NewDatabase(..., keep_uncertainty_data=True)
#
# Disable multiprocessing?
# NewDatabase(..., use_multiprocessing=False)
#
# Hide these messages?
# NewDatabase(..., quiet=True)
#
# //////////////////// EXTRACTING SOURCE DATABASE ////////////////////
# Done!
#
# ////////////////// IMPORTING DEFAULT INVENTORIES ///////////////////
#
# //////////////// IMPORTING USER-DEFINED INVENTORIES ////////////////
# Extracted 1 worksheets in 0.46 seconds
# Migrating to 3.8 first
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# The following datasets to import already exist in the source database. They will not be imported
# +--------------------------------+--------------------------------+----------+-------------+
# |              Name              |       Reference product        | Location |     File    |
# +--------------------------------+--------------------------------+----------+-------------+
# |       bromine, at plant        |       bromine, at plant        |   RER    | lci-PV.xlsx |
# | electricity production, photov |    electricity, low voltage    |    PT    | lci-PV.xlsx |
# | electricity production, photov |    electricity, low voltage    |    IL    | lci-PV.xlsx |
# | electricity production, photov |    electricity, low voltage    |    SE    | lci-PV.xlsx |
# | electricity production, photov |    electricity, low voltage    |    FR    | lci-PV.xlsx |
# | electricity production, photov |    electricity, low voltage    |    TR    | lci-PV.xlsx |
# | electricity production, photov |    electricity, low voltage    |    NZ    | lci-PV.xlsx |
# | electricity production, photov |    electricity, low voltage    |    MY    | lci-PV.xlsx |
# | electricity production, photov |    electricity, low voltage    |    CN    | lci-PV.xlsx |
# | electricity production, photov |    electricity, low voltage    |    TH    | lci-PV.xlsx |
# | electricity production, photov |    electricity, low voltage    |    ZA    | lci-PV.xlsx |
# | electricity production, photov |    electricity, low voltage    |    JP    | lci-PV.xlsx |
# | electricity production, photov |    electricity, low voltage    |    CH    | lci-PV.xlsx |
# | electricity production, photov |    electricity, low voltage    |    DE    | lci-PV.xlsx |
# | electricity production, photov |    electricity, low voltage    |    KR    | lci-PV.xlsx |
# | electricity production, photov |    electricity, low voltage    |    AT    | lci-PV.xlsx |
# | electricity production, photov |    electricity, low voltage    |    GR    | lci-PV.xlsx |
# | electricity production, photov |    electricity, low voltage    |    IE    | lci-PV.xlsx |
# | electricity production, photov |    electricity, low voltage    |    AU    | lci-PV.xlsx |
# | electricity production, photov |    electricity, low voltage    |    IT    | lci-PV.xlsx |
# | electricity production, photov |    electricity, low voltage    |    MX    | lci-PV.xlsx |
# | emulsion polymerisation, polyv | emulsion polymerisation, polyv |   RER    | lci-PV.xlsx |
# |   ethylene bromide, at plant   |   ethylene bromide, at plant   |   RER    | lci-PV.xlsx |
# | fluorspar production, 97% puri |     fluorspar, 97% purity      |   GLO    | lci-PV.xlsx |
# |  hydrogen fluoride production  |       hydrogen fluoride        |   GLO    | lci-PV.xlsx |
# |             iodine             |             iodine             |   RER    | lci-PV.xlsx |
# | metallization paste production | metallization paste, back side |   RER    | lci-PV.xlsx |
# | metallization paste production | metallization paste, back side |   RER    | lci-PV.xlsx |
# | metallization paste production | metallization paste, front sid |   RER    | lci-PV.xlsx |
# |         methyl iodide          |         methyl iodide          |   RER    | lci-PV.xlsx |
# | nitrogen trifluoride, at plant | nitrogen trifluoride, at plant |   RER    | lci-PV.xlsx |
# | open ground construction, on g | open ground construction, on g |   RER    | lci-PV.xlsx |
# |   photovoltaic cell factory    |   photovoltaic cell factory    |    DE    | lci-PV.xlsx |
# | photovoltaic module production | photovoltaic module, building- |   RER    | lci-PV.xlsx |
# | photovoltaic module production | photovoltaic module, building- |   RER    | lci-PV.xlsx |
# | photovoltaic mounting system p | photovoltaic mounting system,  |   RER    | lci-PV.xlsx |
# | photovoltaic mounting system p | photovoltaic mounting system,  |   RER    | lci-PV.xlsx |
# | photovoltaic mounting system p | photovoltaic mounting system,  |   RER    | lci-PV.xlsx |
# | photovoltaic panel factory con |   photovoltaic panel factory   |   GLO    | lci-PV.xlsx |
# |   polyvinylalcohol, at plant   |   polyvinylalcohol, at plant   |   RER    | lci-PV.xlsx |
# | polyvinylbutyral foil, at plan | polyvinylbutyral foil, at plan |   RER    | lci-PV.xlsx |
# | polyvinylbutyral, powder, at p | polyvinylbutyral, powder, at p |   RER    | lci-PV.xlsx |
# |  polyvinylfluoride production  |       polyvinylfluoride        |    US    | lci-PV.xlsx |
# | polyvinylfluoride production,  | polyvinylfluoride, dispersion  |    US    | lci-PV.xlsx |
# | polyvinylfluoride, film produc |    polyvinylfluoride, film     |    US    | lci-PV.xlsx |
# |        silane, at plant        |        silane, at plant        |   RER    | lci-PV.xlsx |
# | silicon production, metallurgi |  silicon, metallurgical grade  |    NO    | lci-PV.xlsx |
# | silicon production, metallurgi |  silicon, metallurgical grade  |    CN    | lci-PV.xlsx |
# | silicon production, metallurgi |  silicon, metallurgical grade  |    US    | lci-PV.xlsx |
# | silicon production, metallurgi |  silicon, metallurgical grade  |   APAC   | lci-PV.xlsx |
# | silicon production, photovolta | silicon production, photovolta |   GLO    | lci-PV.xlsx |
# | silicon production, photovolta | silicon production, photovolta |    CN    | lci-PV.xlsx |
# | silicon production, photovolta | silicon production, photovolta |   APAC   | lci-PV.xlsx |
# | silicon production, photovolta | silicon production, photovolta |    US    | lci-PV.xlsx |
# |   vinyl fluoride production    |         vinyl fluoride         |    US    | lci-PV.xlsx |
# |   wafer factory construction   |         wafer factory          |    DE    | lci-PV.xlsx |
# | electricity production, photov |    electricity, low voltage    |    AU    | lci-PV.xlsx |
# | electricity production, photov |    electricity, low voltage    |    AT    | lci-PV.xlsx |
# | electricity production, photov |    electricity, low voltage    |    BE    | lci-PV.xlsx |
# | electricity production, photov |    electricity, low voltage    |    CA    | lci-PV.xlsx |
# | electricity production, photov |    electricity, low voltage    |    CL    | lci-PV.xlsx |
# | electricity production, photov |    electricity, low voltage    |    CN    | lci-PV.xlsx |
# | electricity production, photov |    electricity, low voltage    |    CZ    | lci-PV.xlsx |
# | electricity production, photov |    electricity, low voltage    |    DK    | lci-PV.xlsx |
# | electricity production, photov |    electricity, low voltage    |    FI    | lci-PV.xlsx |
# | electricity production, photov |    electricity, low voltage    |    FR    | lci-PV.xlsx |
# | electricity production, photov |    electricity, low voltage    |    DE    | lci-PV.xlsx |
# | electricity production, photov |    electricity, low voltage    |    GR    | lci-PV.xlsx |
# | electricity production, photov |    electricity, low voltage    |    HU    | lci-PV.xlsx |
# | electricity production, photov |    electricity, low voltage    |    IE    | lci-PV.xlsx |
# | electricity production, photov |    electricity, low voltage    |    IL    | lci-PV.xlsx |
# | electricity production, photov |    electricity, low voltage    |    IT    | lci-PV.xlsx |
# | electricity production, photov |    electricity, low voltage    |    JP    | lci-PV.xlsx |
# | electricity production, photov |    electricity, low voltage    |    KR    | lci-PV.xlsx |
# | electricity production, photov |    electricity, low voltage    |    LU    | lci-PV.xlsx |
# | electricity production, photov |    electricity, low voltage    |    MY    | lci-PV.xlsx |
# | electricity production, photov |    electricity, low voltage    |    MX    | lci-PV.xlsx |
# | electricity production, photov |    electricity, low voltage    |    NL    | lci-PV.xlsx |
# | electricity production, photov |    electricity, low voltage    |    NZ    | lci-PV.xlsx |
# | electricity production, photov |    electricity, low voltage    |    NO    | lci-PV.xlsx |
# | electricity production, photov |    electricity, low voltage    |    PT    | lci-PV.xlsx |
# | electricity production, photov |    electricity, low voltage    |    ZA    | lci-PV.xlsx |
# | electricity production, photov |    electricity, low voltage    |    ES    | lci-PV.xlsx |
# | electricity production, photov |    electricity, low voltage    |    SE    | lci-PV.xlsx |
# | electricity production, photov |    electricity, low voltage    |    CH    | lci-PV.xlsx |
# | electricity production, photov |    electricity, low voltage    |    TH    | lci-PV.xlsx |
# | electricity production, photov |    electricity, low voltage    |    TR    | lci-PV.xlsx |
# | electricity production, photov |    electricity, low voltage    |    GB    | lci-PV.xlsx |
# | electricity production, photov |    electricity, low voltage    |    US    | lci-PV.xlsx |
# | electricity production, photov |    electricity, low voltage    |    AU    | lci-PV.xlsx |
# | electricity production, photov |    electricity, low voltage    |    AT    | lci-PV.xlsx |
# | electricity production, photov |    electricity, low voltage    |    BE    | lci-PV.xlsx |
# | electricity production, photov |    electricity, low voltage    |    CA    | lci-PV.xlsx |
# | electricity production, photov |    electricity, low voltage    |    CL    | lci-PV.xlsx |
# | electricity production, photov |    electricity, low voltage    |    CN    | lci-PV.xlsx |
# | electricity production, photov |    electricity, low voltage    |    CZ    | lci-PV.xlsx |
# | electricity production, photov |    electricity, low voltage    |    DK    | lci-PV.xlsx |
# | electricity production, photov |    electricity, low voltage    |    FI    | lci-PV.xlsx |
# | electricity production, photov |    electricity, low voltage    |    FR    | lci-PV.xlsx |
# | electricity production, photov |    electricity, low voltage    |    DE    | lci-PV.xlsx |
# | electricity production, photov |    electricity, low voltage    |    GR    | lci-PV.xlsx |
# | electricity production, photov |    electricity, low voltage    |    HU    | lci-PV.xlsx |
# | electricity production, photov |    electricity, low voltage    |    IE    | lci-PV.xlsx |
# | electricity production, photov |    electricity, low voltage    |    IL    | lci-PV.xlsx |
# | electricity production, photov |    electricity, low voltage    |    IT    | lci-PV.xlsx |
# | electricity production, photov |    electricity, low voltage    |    JP    | lci-PV.xlsx |
# | electricity production, photov |    electricity, low voltage    |    KR    | lci-PV.xlsx |
# | electricity production, photov |    electricity, low voltage    |    LU    | lci-PV.xlsx |
# | electricity production, photov |    electricity, low voltage    |    MY    | lci-PV.xlsx |
# | electricity production, photov |    electricity, low voltage    |    MX    | lci-PV.xlsx |
# | electricity production, photov |    electricity, low voltage    |    NL    | lci-PV.xlsx |
# | electricity production, photov |    electricity, low voltage    |    NZ    | lci-PV.xlsx |
# | electricity production, photov |    electricity, low voltage    |    NO    | lci-PV.xlsx |
# | electricity production, photov |    electricity, low voltage    |    PT    | lci-PV.xlsx |
# | electricity production, photov |    electricity, low voltage    |    ZA    | lci-PV.xlsx |
# | electricity production, photov |    electricity, low voltage    |    ES    | lci-PV.xlsx |
# | electricity production, photov |    electricity, low voltage    |    SE    | lci-PV.xlsx |
# | electricity production, photov |    electricity, low voltage    |    CH    | lci-PV.xlsx |
# | electricity production, photov |    electricity, low voltage    |    TH    | lci-PV.xlsx |
# | electricity production, photov |    electricity, low voltage    |    TR    | lci-PV.xlsx |
# | electricity production, photov |    electricity, low voltage    |    GB    | lci-PV.xlsx |
# | electricity production, photov |    electricity, low voltage    |    US    | lci-PV.xlsx |
# +--------------------------------+--------------------------------+----------+-------------+
# Migrating to 3.8 first
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Done!
#
# /////////////////////// EXTRACTING IAM DATA ////////////////////////
# Done!
# #############################################################################################################
# 3.9.1 brightway superstructure
#
# ////////////////////////////// BUSES ///////////////////////////////
# Done!
#
#
# ///////////////////////// PASSENGER CARS ///////////////////////////
# No markets found for car in IAM data. Skipping.
# Extracted 1 worksheets in 3.61 seconds
# Migrating to 3.8 first
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# The following datasets to import already exist in the source database. They will not be imported
# +--------------------------------+--------------------------------+----------+--------------------+
# |              Name              |       Reference product        | Location |        File        |
# +--------------------------------+--------------------------------+----------+--------------------+
# | fuel tank, compressed hydrogen | fuel tank, compressed hydrogen |   GLO    | lci-pass_cars.xlsx |
# | fuel tank, compressed hydrogen |         hydrogen tank          |   RER    | lci-pass_cars.xlsx |
# | fuel tank, compressed natural  | fuel tank, compressed natural  |   RER    | lci-pass_cars.xlsx |
# |     glider lightweighting      |     glider lightweighting      |   GLO    | lci-pass_cars.xlsx |
# +--------------------------------+--------------------------------+----------+--------------------+
# Done!
#
#
# ////////////////////////// TWO-WHEELERS ////////////////////////////
# No markets found for two wheeler in IAM data. Skipping.
# No markets found for two wheeler in IAM data. Skipping.
# Done!
#
# `update_all()` will skip the following steps:
# update_two_wheelers(), update_cars(), and update_buses()
# If you want to update these steps, please run them separately afterwards.
# Done!
#
# Running all checks...
# Anomalies found: check the change report.
# Running all checks...
# Building superstructure database...
# Dropped 0 duplicate(s).
# Scenario difference file exported to /Users/romain/GitHub/premise/dev/export/scenario diff files!
# Writing activities to SQLite3 database:
# 0% [##############################] 100% | ETA: 00:00:00
# Total time elapsed: 00:00:51
# Title: Writing activities to SQLite3 database:
#   Started: 01/30/2024 11:06:34
#   Finished: 01/30/2024 11:07:26
#   Total time elapsed: 00:00:51
#   CPU %: 96.40
#   Memory %: 14.79
# Created database: test_super
# Generate scenario report.
# Report saved under /Users/romain/GitHub/premise/dev/export/scenario_report.
# Generate change report.
# Report saved under /Users/romain/GitHub/premise/dev.
# premise v.(1, 8, 2, 'dev7')
# +------------------------------------------------------------------+
# | Warning                                                          |
# +------------------------------------------------------------------+
# | Because some of the scenarios can yield LCI databases            |
# | containing net negative emission technologies (NET),             |
# | it is advised to account for biogenic CO2 flows when calculating |
# | Global Warming potential indicators.                             |
# | `premise_gwp` provides characterization factors for such flows.  |
# | It also provides factors for hydrogen emissions to air.          |
# |                                                                  |
# | Within your bw2 project:                                         |
# | from premise_gwp import add_premise_gwp                          |
# | add_premise_gwp()                                                |
# +------------------------------------------------------------------+
# +--------------------------------+----------------------------------+
# | Utils functions                | Description                      |
# +--------------------------------+----------------------------------+
# | clear_cache()                  | Clears the cache folder. Useful  |
# |                                | when updating `premise`or        |
# |                                | encountering issues with         |
# |                                | inventories.                     |
# +--------------------------------+----------------------------------+
# | get_regions_definition(model)  | Retrieves the list of countries  |
# |                                | for each region of the model.    |
# +--------------------------------+----------------------------------+
# | ndb.NewDatabase(...)           | Generates a summary of the most  |
# | ndb.generate_scenario_report() | important scenarios' variables.  |
# +--------------------------------+----------------------------------+
# Keep uncertainty data?
# NewDatabase(..., keep_uncertainty_data=True)
#
# Disable multiprocessing?
# NewDatabase(..., use_multiprocessing=False)
#
# Hide these messages?
# NewDatabase(..., quiet=True)
#
# //////////////////// EXTRACTING SOURCE DATABASE ////////////////////
# Done!
#
# ////////////////// IMPORTING DEFAULT INVENTORIES ///////////////////
#
# //////////////// IMPORTING USER-DEFINED INVENTORIES ////////////////
# Extracted 1 worksheets in 0.44 seconds
# Migrating to 3.8 first
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# The following datasets to import already exist in the source database. They will not be imported
# +--------------------------------+--------------------------------+----------+-------------+
# |              Name              |       Reference product        | Location |     File    |
# +--------------------------------+--------------------------------+----------+-------------+
# |       bromine, at plant        |       bromine, at plant        |   RER    | lci-PV.xlsx |
# | electricity production, photov |    electricity, low voltage    |    PT    | lci-PV.xlsx |
# | electricity production, photov |    electricity, low voltage    |    IL    | lci-PV.xlsx |
# | electricity production, photov |    electricity, low voltage    |    SE    | lci-PV.xlsx |
# | electricity production, photov |    electricity, low voltage    |    FR    | lci-PV.xlsx |
# | electricity production, photov |    electricity, low voltage    |    TR    | lci-PV.xlsx |
# | electricity production, photov |    electricity, low voltage    |    NZ    | lci-PV.xlsx |
# | electricity production, photov |    electricity, low voltage    |    MY    | lci-PV.xlsx |
# | electricity production, photov |    electricity, low voltage    |    CN    | lci-PV.xlsx |
# | electricity production, photov |    electricity, low voltage    |    TH    | lci-PV.xlsx |
# | electricity production, photov |    electricity, low voltage    |    ZA    | lci-PV.xlsx |
# | electricity production, photov |    electricity, low voltage    |    JP    | lci-PV.xlsx |
# | electricity production, photov |    electricity, low voltage    |    CH    | lci-PV.xlsx |
# | electricity production, photov |    electricity, low voltage    |    DE    | lci-PV.xlsx |
# | electricity production, photov |    electricity, low voltage    |    KR    | lci-PV.xlsx |
# | electricity production, photov |    electricity, low voltage    |    AT    | lci-PV.xlsx |
# | electricity production, photov |    electricity, low voltage    |    GR    | lci-PV.xlsx |
# | electricity production, photov |    electricity, low voltage    |    IE    | lci-PV.xlsx |
# | electricity production, photov |    electricity, low voltage    |    AU    | lci-PV.xlsx |
# | electricity production, photov |    electricity, low voltage    |    IT    | lci-PV.xlsx |
# | electricity production, photov |    electricity, low voltage    |    MX    | lci-PV.xlsx |
# | emulsion polymerisation, polyv | emulsion polymerisation, polyv |   RER    | lci-PV.xlsx |
# |   ethylene bromide, at plant   |   ethylene bromide, at plant   |   RER    | lci-PV.xlsx |
# | fluorspar production, 97% puri |     fluorspar, 97% purity      |   GLO    | lci-PV.xlsx |
# |  hydrogen fluoride production  |       hydrogen fluoride        |   GLO    | lci-PV.xlsx |
# |             iodine             |             iodine             |   RER    | lci-PV.xlsx |
# | metallization paste production | metallization paste, back side |   RER    | lci-PV.xlsx |
# | metallization paste production | metallization paste, back side |   RER    | lci-PV.xlsx |
# | metallization paste production | metallization paste, front sid |   RER    | lci-PV.xlsx |
# |         methyl iodide          |         methyl iodide          |   RER    | lci-PV.xlsx |
# | nitrogen trifluoride, at plant | nitrogen trifluoride, at plant |   RER    | lci-PV.xlsx |
# | open ground construction, on g | open ground construction, on g |   RER    | lci-PV.xlsx |
# |   photovoltaic cell factory    |   photovoltaic cell factory    |    DE    | lci-PV.xlsx |
# | photovoltaic module production | photovoltaic module, building- |   RER    | lci-PV.xlsx |
# | photovoltaic module production | photovoltaic module, building- |   RER    | lci-PV.xlsx |
# | photovoltaic mounting system p | photovoltaic mounting system,  |   RER    | lci-PV.xlsx |
# | photovoltaic mounting system p | photovoltaic mounting system,  |   RER    | lci-PV.xlsx |
# | photovoltaic mounting system p | photovoltaic mounting system,  |   RER    | lci-PV.xlsx |
# | photovoltaic panel factory con |   photovoltaic panel factory   |   GLO    | lci-PV.xlsx |
# |   polyvinylalcohol, at plant   |   polyvinylalcohol, at plant   |   RER    | lci-PV.xlsx |
# | polyvinylbutyral foil, at plan | polyvinylbutyral foil, at plan |   RER    | lci-PV.xlsx |
# | polyvinylbutyral, powder, at p | polyvinylbutyral, powder, at p |   RER    | lci-PV.xlsx |
# |  polyvinylfluoride production  |       polyvinylfluoride        |    US    | lci-PV.xlsx |
# | polyvinylfluoride production,  | polyvinylfluoride, dispersion  |    US    | lci-PV.xlsx |
# | polyvinylfluoride, film produc |    polyvinylfluoride, film     |    US    | lci-PV.xlsx |
# |        silane, at plant        |        silane, at plant        |   RER    | lci-PV.xlsx |
# | silicon production, metallurgi |  silicon, metallurgical grade  |    NO    | lci-PV.xlsx |
# | silicon production, metallurgi |  silicon, metallurgical grade  |    CN    | lci-PV.xlsx |
# | silicon production, metallurgi |  silicon, metallurgical grade  |    US    | lci-PV.xlsx |
# | silicon production, metallurgi |  silicon, metallurgical grade  |   APAC   | lci-PV.xlsx |
# | silicon production, photovolta | silicon production, photovolta |   GLO    | lci-PV.xlsx |
# | silicon production, photovolta | silicon production, photovolta |    CN    | lci-PV.xlsx |
# | silicon production, photovolta | silicon production, photovolta |   APAC   | lci-PV.xlsx |
# | silicon production, photovolta | silicon production, photovolta |    US    | lci-PV.xlsx |
# |   vinyl fluoride production    |         vinyl fluoride         |    US    | lci-PV.xlsx |
# |   wafer factory construction   |         wafer factory          |    DE    | lci-PV.xlsx |
# | electricity production, photov |    electricity, low voltage    |    AU    | lci-PV.xlsx |
# | electricity production, photov |    electricity, low voltage    |    AT    | lci-PV.xlsx |
# | electricity production, photov |    electricity, low voltage    |    BE    | lci-PV.xlsx |
# | electricity production, photov |    electricity, low voltage    |    CA    | lci-PV.xlsx |
# | electricity production, photov |    electricity, low voltage    |    CL    | lci-PV.xlsx |
# | electricity production, photov |    electricity, low voltage    |    CN    | lci-PV.xlsx |
# | electricity production, photov |    electricity, low voltage    |    CZ    | lci-PV.xlsx |
# | electricity production, photov |    electricity, low voltage    |    DK    | lci-PV.xlsx |
# | electricity production, photov |    electricity, low voltage    |    FI    | lci-PV.xlsx |
# | electricity production, photov |    electricity, low voltage    |    FR    | lci-PV.xlsx |
# | electricity production, photov |    electricity, low voltage    |    DE    | lci-PV.xlsx |
# | electricity production, photov |    electricity, low voltage    |    GR    | lci-PV.xlsx |
# | electricity production, photov |    electricity, low voltage    |    HU    | lci-PV.xlsx |
# | electricity production, photov |    electricity, low voltage    |    IE    | lci-PV.xlsx |
# | electricity production, photov |    electricity, low voltage    |    IL    | lci-PV.xlsx |
# | electricity production, photov |    electricity, low voltage    |    IT    | lci-PV.xlsx |
# | electricity production, photov |    electricity, low voltage    |    JP    | lci-PV.xlsx |
# | electricity production, photov |    electricity, low voltage    |    KR    | lci-PV.xlsx |
# | electricity production, photov |    electricity, low voltage    |    LU    | lci-PV.xlsx |
# | electricity production, photov |    electricity, low voltage    |    MY    | lci-PV.xlsx |
# | electricity production, photov |    electricity, low voltage    |    MX    | lci-PV.xlsx |
# ...
# +--------------------------------+--------------------------------+----------+--------------------+
# | fuel tank, compressed hydrogen | fuel tank, compressed hydrogen |   GLO    | lci-pass_cars.xlsx |
# | fuel tank, compressed hydrogen |         hydrogen tank          |   RER    | lci-pass_cars.xlsx |
# | fuel tank, compressed natural  | fuel tank, compressed natural  |   RER    | lci-pass_cars.xlsx |
# |     glider lightweighting      |     glider lightweighting      |   GLO    | lci-pass_cars.xlsx |
# +--------------------------------+--------------------------------+----------+--------------------+
# Done!
#
#
# ////////////////////////// TWO-WHEELERS ////////////////////////////
# No markets found for two wheeler in IAM data. Skipping.
# Done!
#
# `update_all()` will skip the following steps:
# update_two_wheelers(), update_cars(), and update_buses()
# If you want to update these steps, please run them separately afterwards.
# Extracted 1 worksheets in 4.15 seconds
# Migrating to 3.8 first
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# The following datasets to import already exist in the source database. They will not be imported
# +--------------------------------+--------------------------------+----------+-----------------+
# |              Name              |       Reference product        | Location |       File      |
# +--------------------------------+--------------------------------+----------+-----------------+
# |      electrical equipment      |      electrical equipment      |   RER    | lci-trucks.xlsx |
# |       gearbox, for lorry       |       gearbox, for lorry       |   RER    | lci-trucks.xlsx |
# | fuel tank, for diesel vehicle  |           fuel tank            |   RER    | lci-trucks.xlsx |
# |    transmission, for lorry     |    transmission, for lorry     |   RER    | lci-trucks.xlsx |
# |     suspension, for lorry      |     suspension, for lorry      |   RER    | lci-trucks.xlsx |
# | fuel tank, compressed hydrogen | fuel tank, compressed hydrogen |   GLO    | lci-trucks.xlsx |
# |        storage battery         |        storage battery         |   RER    | lci-trucks.xlsx |
# |  power electronics, for lorry  |  power electronics, for lorry  |   RER    | lci-trucks.xlsx |
# |  lead acid battery, for lorry  |  lead acid battery, for lorry  |   RER    | lci-trucks.xlsx |
# | other components, for hybrid e | other components, for hybrid e |   RER    | lci-trucks.xlsx |
# |            charger             |            charger             |   RER    | lci-trucks.xlsx |
# |          transformers          |          transformers          |   RER    | lci-trucks.xlsx |
# | fuel tank, compressed hydrogen |         hydrogen tank          |   RER    | lci-trucks.xlsx |
# | other components, for electric | other components, for electric |   RER    | lci-trucks.xlsx |
# |      retarder, for lorry       |      retarder, for lorry       |   RER    | lci-trucks.xlsx |
# | assembly operation, for lorry  | assembly operation, for lorry  |   RER    | lci-trucks.xlsx |
# |         charging stand         |         charging stand         |   RER    | lci-trucks.xlsx |
# |   exhaust system, for lorry    |   exhaust system, for lorry    |   RER    | lci-trucks.xlsx |
# |        cabin, for lorry        |        cabin, for lorry        |   RER    | lci-trucks.xlsx |
# | fuel tank, compressed natural  | fuel tank, compressed natural  |   RER    | lci-trucks.xlsx |
# |     glider lightweighting      |     glider lightweighting      |   GLO    | lci-trucks.xlsx |
# | frame, blanks and saddle, for  | frame, blanks and saddle, for  |   RER    | lci-trucks.xlsx |
# | internal combustion engine, fo | internal combustion engine, fo |   RER    | lci-trucks.xlsx |
# |  tires and wheels, for lorry   |  tires and wheels, for lorry   |   RER    | lci-trucks.xlsx |
# +--------------------------------+--------------------------------+----------+-----------------+
# Anomalies found: check the change report.
# Done!
# Done!
# Done!
#
# Running all checks...
# Anomalies found: check the change report.
# Running all checks...
# Building scenario factor file...
# Number of new activities: 34514
# Data package saved at /Users/romain/GitHub/premise/dev/export/datapackage/test.zip
# Generate scenario report.
# Report saved under /Users/romain/GitHub/premise/dev/export/scenario_report.
# Generate change report.
# Report saved under /Users/romain/GitHub/premise/dev.
# The data package contains the following scenarios:
# +-----+---------------------------+------------------------------------------------------------------------------------------------+
# | No. |          Scenario         |                                          Description                                           |
# +-----+---------------------------+------------------------------------------------------------------------------------------------+
# |  0  | remind - SSP2-Base - 2050 | Prospective db, based on REMIND, pathway SSP2-BASE, for the year 2050, and external scenario . |
# |  1  | image - SSP2-RCP19 - 2050 | Prospective db, based on IMAGE, pathway SSP2-RCP19, for the year 2050, and external scenario . |
# +-----+---------------------------+------------------------------------------------------------------------------------------------+
#
# To unfold all scenarios, `unfold()`.
# To unfold a specific scenario, `unfold(scenarios=[1,])`.
# Cannot find cached database. Will create one now for next time...
# Getting activity data
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████| 21238/21238 [00:00<00:00, 235718.24it/s]
# Adding exchange data to activities
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████| 674593/674593 [00:49<00:00, 13679.09it/s]
# Filling out exchange data
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████| 21238/21238 [00:03<00:00, 7025.70it/s]
# Cannot find cached database. Will create one now for next time...
# Getting activity data
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████| 4733/4733 [00:00<00:00, 277009.95it/s]
# Adding exchange data to activities
# 0it [00:00, ?it/s]
# Filling out exchange data
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████| 4733/4733 [00:00<00:00, 4169636.81it/s]
# Extracting additional inventories...
# Writing scenario difference file...
# Generating superstructure database...
# Scenario difference file exported to /Users/romain/GitHub/premise/dev/SDF ecoinvent 3.9 test.csv
#
# Writing superstructure database...
# Writing activities to SQLite3 database:
# 0% [##############################] 100% | ETA: 00:00:00
# Total time elapsed: 00:01:05
# Title: Writing activities to SQLite3 database:
#   Started: 01/30/2024 11:47:49
#   Finished: 01/30/2024 11:48:54
#   Total time elapsed: 00:01:05
#   CPU %: 91.70
#   Memory %: 17.86
# Created database: test
# premise v.(1, 8, 2, 'dev7')
# +------------------------------------------------------------------+
# | Warning                                                          |
# +------------------------------------------------------------------+
# | Because some of the scenarios can yield LCI databases            |
# | containing net negative emission technologies (NET),             |
# | it is advised to account for biogenic CO2 flows when calculating |
# | Global Warming potential indicators.                             |
# | `premise_gwp` provides characterization factors for such flows.  |
# | It also provides factors for hydrogen emissions to air.          |
# |                                                                  |
# | Within your bw2 project:                                         |
# | from premise_gwp import add_premise_gwp                          |
# | add_premise_gwp()                                                |
# +------------------------------------------------------------------+
# +--------------------------------+----------------------------------+
# | Utils functions                | Description                      |
# +--------------------------------+----------------------------------+
# | clear_cache()                  | Clears the cache folder. Useful  |
# |                                | when updating `premise`or        |
# |                                | encountering issues with         |
# |                                | inventories.                     |
# +--------------------------------+----------------------------------+
# | get_regions_definition(model)  | Retrieves the list of countries  |
# |                                | for each region of the model.    |
# +--------------------------------+----------------------------------+
# | ndb.NewDatabase(...)           | Generates a summary of the most  |
# | ndb.generate_scenario_report() | important scenarios' variables.  |
# +--------------------------------+----------------------------------+
# Keep uncertainty data?
# NewDatabase(..., keep_uncertainty_data=True)
#
# Disable multiprocessing?
# NewDatabase(..., use_multiprocessing=False)
#
# Hide these messages?
# NewDatabase(..., quiet=True)
#
# //////////////////// EXTRACTING SOURCE DATABASE ////////////////////
# Cannot find cached database. Will create one now for next time...
# Getting activity data
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████| 18856/18856 [00:00<00:00, 144135.89it/s]
# Adding exchange data to activities
#  77%|██████████████████████████████████████████████████████████████████████████████▎                      | 424053/547208 [00:46<00:13, 9160.40it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 38
#      26 for source in [
#      27     "brightway",
#      28     #"ecospold"
#      29 ]:
#      30     for export in [
#      31         "brightway",
#      32         "superstructure",
#    (...)
#      35         "datapackage"
#      36     ]:
# ---> 38         ndb = NewDatabase(
#      39                 scenarios = scenarios,
#      40                 source_db= f"ecoinvent {ei} {model}" if source == "brightway" else None,
#      41                 source_type=source,
#      42                 source_file_path=f"/Users/romain/Documents/ecoinvent {ei}_cutoff_ecoSpold02/datasets" if source == "ecospold" else None, # <-- this is NEW
#      43                 source_version=ei,
#      44                 key='tUePmX_S5B8ieZkkM7WUU2CnO8SmShwmAeWK9x2rTFo=',
#      45                 system_model=model,
#      46                 system_args=combinations[0],
#      47                 additional_inventories= [ # <-- this is NEW
#      48                     {"filepath": "/Users/romain/GitHub/premise/premise/data/additional_inventories/lci-PV.xlsx", "ecoinvent version": "3.7"}, # <-- this is NEW
#      49             ] # <-- this is NEW
#      50         )
#      53         print("#############################################################################################################")
#      54         print(ei, source, export)
#
# File ~/GitHub/premise/premise/new_database.py:608, in NewDatabase.__init__(self, scenarios, source_version, source_type, key, source_db, source_file_path, additional_inventories, system_model, system_args, use_cached_inventories, use_cached_database, external_scenarios, quiet, keep_uncertainty_data, gains_scenario, use_absolute_efficiency, use_multiprocessing)
#     606 print("\n//////////////////// EXTRACTING SOURCE DATABASE ////////////////////")
#     607 if use_cached_database:
# --> 608     self.database = self.__find_cached_db(source_db)
#     609     print("Done!")
#     610 else:
#
# File ~/GitHub/premise/premise/new_database.py:688, in NewDatabase.__find_cached_db(self, db_name)
#     686 print("Cannot find cached database. Will create one now for next time...")
#     687 clear_existing_cache()
# --> 688 database = self.__clean_database()
#     689 pickle.dump(database, open(file_name, "wb"))
#     690 return database
#
# File ~/GitHub/premise/premise/new_database.py:735, in NewDatabase.__clean_database(self)
#     729 def __clean_database(self) -> List[dict]:
#     730     """
#     731     Extracts the ecoinvent database, loads it into a dictionary and does a little bit of housekeeping
#     732     (adds missing locations, reference products, etc.).
#     733     :return:
#     734     """
# --> 735     return DatabaseCleaner(
#     736         self.source, self.source_type, self.source_file_path, self.version
#     737     ).prepare_datasets(self.keep_uncertainty_data)
#
# File ~/GitHub/premise/premise/clean_datasets.py:155, in DatabaseCleaner.__init__(self, source_db, source_type, source_file_path, version)
#     151     if len(DatabaseChooser(source_db)) == 0:
#     152         raise NameError(
#     153             "The database selected is empty. Make sure the name is correct"
#     154         )
# --> 155     self.database = wurst.extract_brightway2_databases(source_db)
#     156     self.database = remove_categories(self.database)
#     158 if source_type == "ecospold":
#     159     # The ecospold data needs to be formatted
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/premise_env/lib/python3.10/site-packages/wurst/brightway/extract_database.py:170, in extract_brightway2_databases(database_names, add_properties, add_identifiers)
#     168 # Add each exchange to the activity list of exchanges
#     169 print("Adding exchange data to activities")
# --> 170 add_exchanges_to_consumers(activities, exchange_qs, add_properties)
#     171 # Add details on exchanges which come from our databases
#     172 print("Filling out exchange data")
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/premise_env/lib/python3.10/site-packages/wurst/brightway/extract_database.py:83, in add_exchanges_to_consumers(activities, exchange_qs, add_properties, add_identifiers)
#      80 lookup = {(o["database"], o["code"]): o for o in activities}
#      82 with tqdm(total=exchange_qs.count()) as pbar:
# ---> 83     for i, exc in enumerate(exchange_qs):
#      84         exc = extract_exchange(exc, add_properties=add_properties)
#      85         output = tuple(exc.pop("output"))
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/premise_env/lib/python3.10/site-packages/peewee.py:4612, in ResultIterator.next(self)
#    4610     obj = self.cursor_wrapper.row_cache[self.index]
#    4611 elif not self.cursor_wrapper.populated:
# -> 4612     self.cursor_wrapper.iterate()
#    4613     obj = self.cursor_wrapper.row_cache[self.index]
#    4614 else:
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/premise_env/lib/python3.10/site-packages/peewee.py:4532, in CursorWrapper.iterate(self, cache)
#    4530     self.initialized = True
#    4531 self.count += 1
# -> 4532 result = self.process_row(row)
#    4533 if cache:
#    4534     self.row_cache.append(result)
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/premise_env/lib/python3.10/site-packages/peewee.py:7789, in ModelObjectCursorWrapper.process_row(self, row)
#    7788 def process_row(self, row):
# -> 7789     data = super(ModelObjectCursorWrapper, self).process_row(row)
#    7790     if self.is_model:
#    7791         # Clear out any dirty fields before returning to the user.
#    7792         obj = self.constructor(__no_default__=1, **data)
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/premise_env/lib/python3.10/site-packages/peewee.py:7755, in ModelDictCursorWrapper.process_row(self, row)
#    7753 if attr in result: continue  # Don't overwrite if we have dupes.
#    7754 if converters[i] is not None:
# -> 7755     result[attr] = converters[i](row[i])
#    7756 else:
#    7757     result[attr] = row[i]
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/premise_env/lib/python3.10/site-packages/bw2data/sqlite.py:20, in PickleField.python_value(self, value)
#      19 def python_value(self, value):
# ---> 20     return pickle.loads(bytes(value))
#
# KeyboardInterrupt:
